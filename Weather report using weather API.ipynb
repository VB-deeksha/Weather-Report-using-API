# %% [markdown]
# # Weather Report by APIs

# %%
import requests
import os
from datetime import datetime

# %% [markdown]
# ![api.jpg](attachment:api.jpg)

# %%
#posted api call= https://api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}
user_api = os.environ['current_weather_data']
location = input("Enter the city name: ")

complete_api_link = "https://api.openweathermap.org/data/2.5/weather?q="+ location+"&appid=" +user_api
api_link = requests.get(complete_api_link)
api_data = api_link.json()

if api_data['cod'] == '404':
    print("Invalid City: {}, Please chech your City name".format(location))
else:
    temp_city = ((api_data['main']['temp']) - 273.15)
    weather_desc = api_data['weather'][0]['description']
    hmdt = api_data['main']['humidity']
    wind_spd = api_data['wind']['speed']
    date_time = datetime.now().strftime("%d %b %Y | %I:%M:%S %p")
    
    print("-----------------------------------------------------------------")
    print("Weather Stats for - {} || {}".format(location.upper(), date_time))
    print("-----------------------------------------------------------------")
    
    print("Current Temperature is: {:.2f} deg C".format(temp_city))
    print("Current weather desc  :",weather_desc)
    print("Current Humidity      :",hmdt, '%')
    print("Current wind speed    :",wind_spd, 'kmph')
# Out:
# Enter the city name: Bangalore
# -----------------------------------------------------------------
# Weather Stats for - BANGALORE || 07 Jan 2024 | 02:18:52 PM
# -----------------------------------------------------------------
# Current Temperature is: 25.61 deg C
# Current weather desc  : broken clouds
# Current Humidity      : 52 %
# Current wind speed    : 5.33 kmph

# %% [markdown]
# ![weather_API.webp](attachment:weather_API.webp)
